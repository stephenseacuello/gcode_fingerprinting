# %% [markdown]
# # 06 - Dashboard Usage
#
# Explore the FastAPI interactive dashboard.
#
# ## Learning Objectives
# - Access Swagger UI
# - Test API endpoints interactively
# - View model information
# - Monitor API health

# %% [markdown]
# ## 1. Access Dashboard
#
# Once the API server is running, visit:
#
# **http://localhost:8000/docs**
#
# This opens the interactive Swagger UI.

# %% [markdown]
# ## 2. Available Endpoints
#
# - `GET /`: API information
# - `GET /health`: Health check
# - `GET /info`: Model details
# - `POST /predict`: Single prediction
# - `POST /batch_predict`: Batch predictions
# - `POST /fingerprint`: Extract fingerprint
# - `POST /load_checkpoint`: Load new checkpoint

# %% [markdown]
# ## 3. Interactive Testing
#
# In the Swagger UI:
# 1. Click on any endpoint
# 2. Click 'Try it out'
# 3. Fill in request parameters
# 4. Click 'Execute'
# 5. View response

# %% [markdown]
# ## Summary
#
# You learned:
# - Accessing the Swagger dashboard
# - Testing endpoints interactively
# - Viewing API documentation
#
# ## Next Steps
#
# Continue to **07_hyperparameter_sweeps.ipynb** for W&B optimization.
